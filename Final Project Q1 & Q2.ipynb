# %% [markdown]
# ### Question 1
# Create a function named calculate() in mean_var_std.py that uses Numpy to output the mean, variance, standard deviation, max, min, and sum of the rows, columns, and elements in a 3 x 3 matrix.
#
# The input of the function should be a list containing 9 digits. The function should convert the list into a 3 x 3 Numpy array, and then return a dictionary containing the mean, variance, standard deviation, max, min, and sum along both axes and for the flattened matrix.

# %%
import numpy as np

def calculate(numbers):
    if len(numbers) != 9:
        raise ValueError("List must contain nine numbers.")
    data = np.reshape(np.array(numbers),(3,3))
    calculations = {}
    calculations['mean'] = [np.mean(data, axis=0).tolist(), np.mean(data, axis=1).tolist(), np.mean(data.flatten()).tolist()]
    calculations['variance'] = [np.var(data, axis=0).tolist(), np.var(data, axis=1).tolist(), np.var(data.flatten()).tolist()]
    calculations['standard deviation'] = [np.std(data, axis=0).tolist(), np.std(data, axis=1).tolist(), np.std(data.flatten()).tolist()]
    calculations['max'] = [np.max(data, axis=0).tolist(), np.max(data, axis=1).tolist(), np.max(data.flatten()).tolist()]
    calculations['min'] = [np.min(data, axis=0).tolist(), np.min(data, axis=1).tolist(), np.min(data.flatten()).tolist()]
    calculations['sum'] = [np.sum(data, axis=0).tolist(), np.sum(data, axis=1).tolist(), np.sum(data.flatten()).tolist()]
    return calculations

# %%
calculate([1,2,3,4,5,6,7,8,9])
# Out:
# {'mean': [[4.0, 5.0, 6.0], [2.0, 5.0, 8.0], 5.0],
#  'variance': [[6.0, 6.0, 6.0],
#   [0.6666666666666666, 0.6666666666666666, 0.6666666666666666],
#   6.666666666666667],
#  'standard deviation': [[2.449489742783178,
#    2.449489742783178,
#    2.449489742783178],
#   [0.816496580927726, 0.816496580927726, 0.816496580927726],
#   2.581988897471611],
#  'max': [[7, 8, 9], [3, 6, 9], 9],
#  'min': [[1, 2, 3], [1, 4, 7], 1],
#  'sum': [[12, 15, 18], [6, 15, 24], 45]}

# %% [markdown]
# ### Question 2
# In this challenge you must analyze demographic data using Pandas. You are given a dataset of demographic data that was extracted from the 1994 Census database. Here is a sample of what the data looks like:
#
# <img src="Q2.png"
#     style="width:500px; float: middle; margin: 10px 100px 10px 100px; align: center"></img>
#
# #### You must use Pandas to answer the following questions:
#
# ##### 1. How many people of each race are represented in this dataset? This should be a Pandas series with race names as the index labels. (race column)
# ##### 2. What is the average age of men?
# ##### 3. What is the percentage of people who have a Bachelor's degree?
# ##### 4. What percentage of people with advanced education (Bachelors, Masters, or Doctorate) make more than 50K?
# ##### 5. What percentage of people without advanced education make more than 50K?
# ##### 6. What is the minimum number of hours a person works per week?
# ##### 7. What percentage of the people who work the minimum number of hours per week have a salary of more than 50K?
# ##### 8. What country has the highest percentage of people that earn >50K and what is that percentage?
# ##### 9. Identify the most popular occupation for those who earn >50K in India.
#
# Use the starter code in the file demographic_data_analyzer. Update the code so all variables set to "None" are set to the appropriate calculation or code. Round all decimals to the nearest tenth.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Use blue boxes (alert-info) for tips and notes.
# If it’s a note, you don’t have to include the word “Note”.
# </div>

# %% [markdown]
# #### Q1

# %%
#Q1
import pandas as pd
filepath = "adult.data.csv"

# %%
import csv
with open(r"C:\Users\alber\Documents\Online Course\FreeCodeCamp\adult.data") as input_file:
   lines = input_file.readlines()
   newLines = []
   for line in lines:
      newLine = line.strip().split(", ")
      newLines.append(newLine)

with open('output.csv', 'w') as test_file:
   file_writer = csv.writer(test_file)
   file_writer.writerows(newLines)

# %%
column_names = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']
pd.read_csv("adultdata.csv",
            header=None,
            names = column_names)['age']
# Out:
# 0        39.0
# 1        50.0
# 2        38.0
# 3        53.0
# 4        28.0
#          ...
# 32557    40.0
# 32558    58.0
# 32559    22.0
# 32560    52.0
# 32561     NaN
# Name: age, Length: 32562, dtype: float64

# %%
column_names = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']
df_demograph = pd.read_csv("adultdata.csv",
                          header=None,
                          names = column_names)

# %%
df_demograph
# Out:
#         age         workclass    fnlwgt  education  education-num  \
# 0      39.0         State-gov   77516.0  Bachelors           13.0
# 1      50.0  Self-emp-not-inc   83311.0  Bachelors           13.0
# 2      38.0           Private  215646.0    HS-grad            9.0
# 3      53.0           Private  234721.0       11th            7.0
# 4      28.0           Private  338409.0  Bachelors           13.0
# ...     ...               ...       ...        ...            ...
# 32557  40.0           Private  154374.0    HS-grad            9.0
# 32558  58.0           Private  151910.0    HS-grad            9.0
# 32559  22.0           Private  201490.0    HS-grad            9.0
# 32560  52.0      Self-emp-inc  287927.0    HS-grad            9.0
# 32561   NaN               NaN       NaN        NaN            NaN
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
#df_demograph.to_csv('adultdatacsv')

# %%
df_demograph.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32562 entries, 0 to 32561
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  float64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  float64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  float64
#  11  capital-loss    32561 non-null  float64
#  12  hours-per-week  32561 non-null  float64
#  13  native-country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: float64(6), object(9)
# memory usage: 3.7+ MB

# %%
df_demograph.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df_demograph.loc[df_demograph['race']=='White']
# Out:
#         age         workclass    fnlwgt   education  education-num  \
# 0      39.0         State-gov   77516.0   Bachelors           13.0
# 1      50.0  Self-emp-not-inc   83311.0   Bachelors           13.0
# 2      38.0           Private  215646.0     HS-grad            9.0
# 5      37.0           Private  284582.0     Masters           14.0
# 7      52.0  Self-emp-not-inc  209642.0     HS-grad            9.0
# ...     ...               ...       ...         ...            ...
# 32556  27.0           Private  257302.0  Assoc-acdm           12.0
# 32557  40.0           Private  154374.0     HS-grad            9.0
# 32558  58.0           Private  151910.0     HS-grad            9.0
# 32559  22.0           Private  201490.0     HS-grad            9.0
# 32560  52.0      Self-emp-inc  287927.0     HS-grad            9.0
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df_demograph['sex']=df_demograph['sex'].convert_dtypes()

# %%
df_demograph['race']=='White'
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 32557     True
# 32558     True
# 32559     True
# 32560     True
# 32561    False
# Name: race, Length: 32562, dtype: bool

# %%
race_counts = df_demograph['race'].value_counts().to_frame()
race_counts
# Out:
#                      race
# White               27816
# Black                3124
# Asian-Pac-Islander   1039
# Amer-Indian-Eskimo    311
# Other                 271

# %%
a = df_demograph.groupby('race')
a.get_group(' White')
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 5       37            Private  284582      Masters             14
# 7       52   Self-emp-not-inc  209642      HS-grad              9
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
average_age_men = round(df_demograph.groupby('sex')['age'].mean()['Male'], 1)
average_age_men
# Out:
# 39.4

# %% [markdown]
# #### Q3
# What is the percentage of people who have a Bachelor's degree?

# %%
df_demograph[df_demograph['education']=='Bachelors'].count()
# Out:
# age               5355
# workclass         5355
# fnlwgt            5355
# education         5355
# education-num     5355
# marital-status    5355
# occupation        5355
# relationship      5355
# race              5355
# sex               5355
# capital-gain      5355
# capital-loss      5355
# hours-per-week    5355
# native-country    5355
# income            5355
# dtype: int64

# %%
a = df_demograph['education'].value_counts().to_frame()

# %%
a.sum()
# Out:
# C:\Users\alber\AppData\Local\Temp\ipykernel_6356\359836184.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   a.sum()
# age                                                        303935.0
# workclass         State-govSelf-emp-not-incPrivatePrivatePrivate...
# fnlwgt                                                 1394031633.0
# education         BachelorsBachelorsBachelorsMastersMastersBache...
# education-num                                              100345.0
# marital-status    Never-marriedMarried-civ-spouseMarried-civ-spo...
# occupation        Adm-clericalExec-managerialProf-specialtyExec-...
# relationship      Not-in-familyHusbandWifeWifeNot-in-familyHusba...
# race              WhiteWhiteBlackWhiteWhiteWhiteAsian-Pac-Island...
# capital-gain                                             15790351.0
# ...

# %%
percentage_bachelors = (df_demograph['education'].value_counts()['Bachelors'])/df_demograph['education'].count()*100
# Out:
# 16.44605509658794

# %%
percentage_bachelors = round(df_demograph['education'].value_counts(normalize=True)['Bachelors'] * 100.0, 1 )
percentage_bachelors
# Out:
# 16.4

# %% [markdown]
# #### Q4 & Q5
# What percentage of people with advanced education (Bachelors, Masters, or Doctorate) make more than 50K?

# %%
df_demograph.loc[df_demograph['education'].isin(['Bachelors', 'Masters', 'Doctorate'])].['income']=='>50K'
# Out:
#   File "C:\Users\alber\AppData\Local\Temp\ipykernel_6356\1571336593.py", line 1
#     df_demograph.loc[df_demograph['education'].isin(['Bachelors', 'Masters', 'Doctorate'])].['income']=='>50K'
#                                                                                             ^
# SyntaxError: invalid syntax

# %%
higher_education=df_demograph.loc[df_demograph['education'].isin(['Bachelors', 'Masters', 'Doctorate'])]
higher_education
# Out:
#         age         workclass    fnlwgt  education  education-num  \
# 0      39.0         State-gov   77516.0  Bachelors           13.0
# 1      50.0  Self-emp-not-inc   83311.0  Bachelors           13.0
# 4      28.0           Private  338409.0  Bachelors           13.0
# 5      37.0           Private  284582.0    Masters           14.0
# 8      31.0           Private   45781.0    Masters           14.0
# ...     ...               ...       ...        ...            ...
# 32538  38.0           Private  139180.0  Bachelors           13.0
# 32539  71.0                 ?  287372.0  Doctorate           16.0
# 32544  31.0           Private  199655.0    Masters           14.0
# 32553  32.0           Private  116138.0    Masters           14.0
# 32554  53.0           Private  321865.0    Masters           14.0
#
#            marital-status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# ...

# %%
lower_education=df_demograph.loc[~df_demograph['education'].isin(['Bachelors', 'Masters', 'Doctorate'])]
lower_education
# Out:
#         age         workclass    fnlwgt     education  education-num  \
# 2      38.0           Private  215646.0       HS-grad            9.0
# 3      53.0           Private  234721.0          11th            7.0
# 6      49.0           Private  160187.0           9th            5.0
# 7      52.0  Self-emp-not-inc  209642.0       HS-grad            9.0
# 10     37.0           Private  280464.0  Some-college           10.0
# ...     ...               ...       ...           ...            ...
# 32557  40.0           Private  154374.0       HS-grad            9.0
# 32558  58.0           Private  151910.0       HS-grad            9.0
# 32559  22.0           Private  201490.0       HS-grad            9.0
# 32560  52.0      Self-emp-inc  287927.0       HS-grad            9.0
# 32561   NaN               NaN       NaN           NaN            NaN
#
#               marital-status         occupation   relationship   race     sex  \
# ...

# %%
high_education_percentage = ((higher_education['income']=='>50K').sum())/len(higher_education)
high_education_percentage
# Out:
# 0.46535843011613937

# %%
low_education_percentage = ((lower_education['income']=='>50K').sum())/len(lower_education)
low_education_percentage
# Out:
# 0.17370667304854215

# %%
#higher_education =  df_demograph.loc[df_demograph['education'].isin(['Bachelors', 'Masters', 'Doctorate'])]
#lower_education = df_demograph.loc[~df_demograph['education'].isin(['Bachelors', 'Masters', 'Doctorate'])]

# %%
higher_education =  df_demograph.loc[df_demograph['education'].isin(['Bachelors', 'Masters', 'Doctorate'])]
lower_education = df_demograph.loc[~df_demograph['education'].isin(['Bachelors', 'Masters', 'Doctorate'])]

higher_education_rich = round(100.0 * (higher_education['income'] == '>50K').sum() / len(higher_education), 1 )
lower_education_rich = round(100.0 * (lower_education['income'] == '>50K').sum() / len(lower_education), 1 )

higher_education_rich
# Out:
# 46.5

# %%
lower_education_rich
# Out:
# 17.4

# %% [markdown]
# #### Q6 & Q7
# 6. What is the minimum number of hours a person works per week?
# 7. What percentage of the people who work the minimum number of hours per week have a salary of more than 50K?

# %%
min_work_hours=df_demograph['hours-per-week'].min()
min_work_hours
# Out:
# 1.0

# %%
num_work_hours = df_demograph.loc[df_demograph['hours-per-week']==df_demograph['hours-per-week'].min()]
num_work_hours
# Out:
#         age         workclass    fnlwgt     education  education-num  \
# 189    58.0         State-gov  109567.0     Doctorate           16.0
# 1036   66.0      Self-emp-inc  150726.0           9th            5.0
# 1262   69.0                 ?  195779.0     Assoc-voc           11.0
# 5590   78.0                 ?  363134.0       HS-grad            9.0
# 5632   45.0                 ?  189564.0       Masters           14.0
# 5766   62.0                 ?   97231.0  Some-college           10.0
# 5808   76.0                 ?  211574.0          10th            6.0
# 8447   67.0                 ?  244122.0     Assoc-voc           11.0
# 9147   75.0                 ?  260543.0          10th            6.0
# 11451  27.0           Private  147951.0       HS-grad            9.0
# 19337  72.0                 ?   76860.0       HS-grad            9.0
# 19750  23.0           Private   72887.0       HS-grad            9.0
# 20072  65.0                 ?   76043.0       HS-grad            9.0
# ...

# %%
percentage_rich=(num_work_hours['income']=='>50K').sum()/len(num_work_hours)*100
percentage_rich
# Out:
# 10.0

# %%
#df_demograph['fnlwgt'] = df_demograph.fnlwgt.apply(lambda x: ' '.join(x.strip().split(' ')))

# %% [markdown]
# #### Q8 & Q9
# 8. What country has the highest percentage of people that earn >50K and what is that percentage?
# 9. Identify the most popular occupation for those who earn >50K in India.

# %%
df_demograph.groupby('native-country')[['income']=='>50K'].count().max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6356\2543809395.py in <module>
# ----> 1 df_demograph.groupby('native-country')[['income']=='>50K'].count().max()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1336                 stacklevel=find_stack_level(),
#    1337             )
# -> 1338         return super().__getitem__(key)
#    1339
#    1340     def _gotitem(self, key, ndim: int, subset=None):
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     248         else:
#     249             if key not in self.obj:
# --> 250                 raise KeyError(f"Column not found: {key}")
#     251             subset = self.obj[key]
#     252             ndim = subset.ndim
#
# KeyError: 'Column not found: False'

# %%
aw = df_demograph['income'].mask(df_demograph['income'].ne('>50K'))
#df_demograph.groupby(['native-country'])['income'].count()
aw
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 32557    >50K
# 32558     NaN
# 32559     NaN
# 32560    >50K
# 32561     NaN
# Name: income, Length: 32562, dtype: object

# %%
 df_demograph['income'].mask(df_demograph['income'].ne('>50K'))
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 32557    >50K
# 32558     NaN
# 32559     NaN
# 32560    >50K
# 32561     NaN
# Name: income, Length: 32562, dtype: object

# %%
df_demograph.mask(k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6356\309886575.py in <module>
# ----> 1 mask(k)
#
# NameError: name 'mask' is not defined

# %%
df_demograph['income'] = df_demograph['income'].mask(df_demograph['income'].ne('>50K'))
df_demograph.groupby(['native-country'])['income'].count()
# Out:
# native-country
# ?                              146
# Cambodia                         7
# Canada                          39
# China                           20
# Columbia                         2
# Cuba                            25
# Dominican-Republic               2
# Ecuador                          4
# El-Salvador                      9
# England                         30
# France                          12
# Germany                         44
# Greece                           8
# Guatemala                        3
# Haiti                            4
# Holand-Netherlands               0
# Honduras                         1
# Hong                             6
# Hungary                          3
# India                           40
# Iran                            18
# Ireland                          5
# Italy                           25
# Jamaica                         10
# Japan                           24
# Laos                             2
# ...

# %%
for row in df_demograph:
    print(row)
# Out:
# age
# workclass
# fnlwgt
# education
# education-num
# marital-status
# occupation
# relationship
# race
# sex
# capital-gain
# capital-loss
# hours-per-week
# native-country
# income

# %%
#a=['a', 'a', 'a', 'a', 'a']
#for b, c in df_demograph.iterrows() :
#    print(b, c)\
df_demograph.groupby(['native-country'])['income'].count()
# Out:
# native-country
# ?                               583
# Cambodia                         19
# Canada                          121
# China                            75
# Columbia                         59
# Cuba                             95
# Dominican-Republic               70
# Ecuador                          28
# El-Salvador                     106
# England                          90
# France                           29
# Germany                         137
# Greece                           29
# Guatemala                        64
# Haiti                            44
# Holand-Netherlands                1
# Honduras                         13
# Hong                             20
# Hungary                          13
# India                           100
# Iran                             43
# Ireland                          24
# Italy                            73
# Jamaica                          81
# Japan                            62
# ...

# %%
#a=['a', 'a', 'a', 'a', 'a']
for a, c in df_demograph[['income','native-country']] :
    print(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6356\1870552571.py in <module>
#       1 #a=['a', 'a', 'a', 'a', 'a']
# ----> 2 for a, c in df_demograph[['income','native-country']] :
#       3     print(c)
#
# ValueError: too many values to unpack (expected 2)

# %%
next(df_demograph.iterrows())[1]
# Out:
# age                        39.0
# workclass             State-gov
# fnlwgt                  77516.0
# education             Bachelors
# education-num              13.0
# marital-status    Never-married
# occupation         Adm-clerical
# relationship      Not-in-family
# race                      White
# sex                        Male
# capital-gain             2174.0
# capital-loss                0.0
# hours-per-week             40.0
# native-country    United-States
# income                      NaN
# Name: 0, dtype: object

# %%
df_demograph.groupby('native-country')

# %%
df_demograph['income'][0]
# Out:
# '<=50K'

# %%
df_demograph.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x00000197991C1270>

# %%
df_demograph['income']
# Out:
# 0        <=50K
# 1        <=50K
# 2        <=50K
# 3        <=50K
# 4        <=50K
#          ...
# 32557     >50K
# 32558    <=50K
# 32559    <=50K
# 32560     >50K
# 32561      NaN
# Name: income, Length: 32562, dtype: object

# %%
highest_earning_country = None
highest_earning_country_percentage = 0.0
for country, data in df_demograph.groupby('native-country'):
    percentage = (data['income'] == '>50K').sum() / data['income'].count()
    if highest_earning_country_percentage < percentage:
        highest_earning_country_percentage = percentage
        highest_earning_country = country
highest_earning_country_percentage = round(100 * highest_earning_country_percentage,1)

# %%
highest_earning_country
# Out:
# 'Iran'

# %%
df_demograph[(df_demograph['income'] == '>50K') & (df_demograph['native-country'] == 'India')]['occupation'].value_counts().keys()[0]
# Out:
# 'Prof-specialty'

# %%
df_demograph[df_demograph['native-country']=='Iran']['income'].value_counts().to_frame()
# Out:
#        income
# <=50K      25
# >50K       18

# %%
df_demograph[df_demograph['native-country']=='United-States']['income'].value_counts().to_frame()
# Out:
#        income
# <=50K   21999
# >50K     7171

# %% [markdown]
# ### TO WRAP UP QUESTION 2

# %%
import pandas as pd

def demographic_data_analyzer(print_data=True):
    #Read data, create dataframe from CSV file.
    column_names = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']
    df_demograph = pd.read_csv("adultdata.csv",
                               header=None,
                               names = column_names)
# 1. How many people of each race are represented in this dataset? This should be a Pandas series with race names as the index labels. (race column)
    race_counts = df_demograph['race'].value_counts().to_frame()     
                               
# 2. What is the average age of men?
    average_age_men = round(df_demograph.groupby('sex')['age'].mean()['Male'], 1)

# 3. What is the percentage of people who have a Bachelor's degree?
    percentage_bachelors = (df_demograph['education'].value_counts()['Bachelors'])/df_demograph['education'].count()*100
    
# 4. What percentage of people with advanced education (Bachelors, Masters, or Doctorate) make more than 50K?
    high_education_rich_percentage = ((higher_education['income']=='>50K').sum())/len(higher_education)
    
# 5. What percentage of people without advanced education make more than 50K?
    low_education_rich_percentage = ((lower_education['income']=='>50K').sum())/len(lower_education)

# 6. What is the minimum number of hours a person works per week?
    min_work_hours = df_demograph['hours-per-week'].min()
    
# 7. What percentage of the people who work the minimum number of hours per week have a salary of more than 50K?
    num_work_hours = df_demograph.loc[df_demograph['hours-per-week']==df_demograph['hours-per-week'].min()]
    min_wh_percentage_rich = (num_work_hours['income']=='>50K').sum()/len(num_work_hours)*100
    
# 8. What country has the highest percentage of people that earn >50K and what is that percentage?
    highest_earning_country = None
    highest_earning_country_percentage = 0.0
    for country, data in df_demograph.groupby('native-country'):
        percentage = (data['income'] == '>50K').sum() / data['income'].count()
        if highest_earning_country_percentage < percentage:
            highest_earning_country_percentage = percentage
            highest_earning_country = country
    highest_earning_country_percentage = round(100 * highest_earning_country_percentage,1)
    
# 9. Identify the most popular occupation for those who earn >50K in India.   
    most_popular_occupation = df_demograph[(df_demograph['income'] == '>50K') & (df_demograph['native-country'] == 'India')]['occupation'].value_counts().keys()[0]
    
        # DO NOT MODIFY BELOW THIS LINE

    if print_data:
        print("Number of each race:\n", race_counts) 
        print("Average age of men:", average_age_men)
        print(f"Percentage with Bachelors degrees: {percentage_bachelors}%")
        print(f"Percentage with higher education that earn >50K: {high_education_rich_percentage}%")
        print(f"Percentage without higher education that earn >50K: {low_education_rich_percentage}%")
        print(f"Min work time: {min_work_hours} hours/week")
        print(f"Percentage of rich among those who work fewest hours: {min_wh_percentage_rich}%")
        print("Country with highest percentage of rich:", highest_earning_country)
        print(f"Highest percentage of rich people in country: {highest_earning_country_percentage}%")
        print("Top occupations in India:", most_popular_occupation)

    return {
        'race_counts': race_counts,
        'average_age_men': average_age_men,
        'percentage_bachelors': percentage_bachelors,
        'higher_education_rich': high_education_rich_percentage,
        'lower_education_rich': low_education_rich_percentage,
        'min_work_hours': min_work_hours,
        'rich_percentage': min_wh_percentage_rich,
        'highest_earning_country': highest_earning_country,
        'highest_earning_country_percentage':highest_earning_country_percentage,
        'top_IN_occupation': most_popular_occupation}

# %%
demographic_data_analyzer()
# Out:
# Number of each race:
#                       race
# White               27816
# Black                3124
# Asian-Pac-Islander   1039
# Amer-Indian-Eskimo    311
# Other                 271
# Average age of men: 39.4
# Percentage with Bachelors degrees: 16.44605509658794%
# Percentage with higher education that earn >50K: 0.46535843011613937%
# Percentage without higher education that earn >50K: 0.17370667304854215%
# Min work time: 1.0 hours/week
# Percentage of rich among those who work fewest hours: 10.0%
# Country with highest percentage of rich: Iran
# Highest percentage of rich people in country: 41.9%
# Top occupations in India: Prof-specialty
# {'race_counts':                      race
#  White               27816
#  Black                3124
#  Asian-Pac-Islander   1039
#  Amer-Indian-Eskimo    311
#  Other                 271,
#  'average_age_men': 39.4,
#  'percentage_bachelors': 16.44605509658794,
#  'higher_education_rich': 0.46535843011613937,
# ...

# %%
a = ['Apple', 'Banana']

# %%
a[not Banana]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6356\2072290041.py in <module>
# ----> 1 a[not Banana]
#
# NameError: name 'Banana' is not defined

# %%
import pandas as pd


def calculate_demographic_data(print_data=True):
    # Read data from file
    df = None

    # How many of each race are represented in this dataset? This should be a Pandas series with race names as the index labels.
    race_count = None

    # What is the average age of men?
    average_age_men = None

    # What is the percentage of people who have a Bachelor's degree?
    percentage_bachelors = None

    # What percentage of people with advanced education (`Bachelors`, `Masters`, or `Doctorate`) make more than 50K?
    # What percentage of people without advanced education make more than 50K?

    # with and without `Bachelors`, `Masters`, or `Doctorate`
    higher_education = None
    lower_education = None

    # percentage with salary >50K
    higher_education_rich = None
    lower_education_rich = None

    # What is the minimum number of hours a person works per week (hours-per-week feature)?
    min_work_hours = None

    # What percentage of the people who work the minimum number of hours per week have a salary of >50K?
    num_min_workers = None

    rich_percentage = None

    # What country has the highest percentage of people that earn >50K?
    highest_earning_country = None
    highest_earning_country_percentage = None

    # Identify the most popular occupation for those who earn >50K in India.
    top_IN_occupation = None

    # DO NOT MODIFY BELOW THIS LINE

    if print_data:
        print("Number of each race:\n", race_count) 
        print("Average age of men:", average_age_men)
        print(f"Percentage with Bachelors degrees: {percentage_bachelors}%")
        print(f"Percentage with higher education that earn >50K: {higher_education_rich}%")
        print(f"Percentage without higher education that earn >50K: {lower_education_rich}%")
        print(f"Min work time: {min_work_hours} hours/week")
        print(f"Percentage of rich among those who work fewest hours: {rich_percentage}%")
        print("Country with highest percentage of rich:", highest_earning_country)
        print(f"Highest percentage of rich people in country: {highest_earning_country_percentage}%")
        print("Top occupations in India:", top_IN_occupation)

    return {
        'race_count': race_count,
        'average_age_men': average_age_men,
        'percentage_bachelors': percentage_bachelors,
        'higher_education_rich': higher_education_rich,
        'lower_education_rich': lower_education_rich,
        'min_work_hours': min_work_hours,
        'rich_percentage': rich_percentage,
        'highest_earning_country': highest_earning_country,
        'highest_earning_country_percentage':
        highest_earning_country_percentage,
        'top_IN_occupation': top_IN_occupation
    }

# %%
calculate_demographic_data(print_data=True)
# Out:
# Number of each race:
#  None
# Average age of men: None
# Percentage with Bachelors degrees: None%
# Percentage with higher education that earn >50K: None%
# Percentage without higher education that earn >50K: None%
# Min work time: None hours/week
# Percentage of rich among those who work fewest hours: None%
# Country with highest percentage of rich: None
# Highest percentage of rich people in country: None%
# Top occupations in India: None
# {'race_count': None,
#  'average_age_men': None,
#  'percentage_bachelors': None,
#  'higher_education_rich': None,
#  'lower_education_rich': None,
#  'min_work_hours': None,
#  'rich_percentage': None,
#  'highest_earning_country': None,
#  'highest_earning_country_percentage': None,
#  'top_IN_occupation': None}
